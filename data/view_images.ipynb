# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
fname = 'LunarLander-v2_img_1_30.npz'

# %%
data = np.load(fname)

# %%
def view_image(episode, step):
    plt.imshow(data[data.files[episode]][step])

# %%
view_image(0, 1)

# %%
view_image(0, 1)

# %%
view_image(0, 1)

# %%
view_image(0, -1)

# %%
view_image(0, -1)

# %%
view_image(0, -1)

# %%
view_image(0, -1)
